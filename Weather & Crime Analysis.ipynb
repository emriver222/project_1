# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
import random
from datetime import datetime

# %% [markdown]
# ### READ IN CSV's & CREATE DATAFRAMES

# %%
#Monthly weather CSV read & DataFrame
weather_path = "Output/Weather_AvgTemp_Monthly"
weather_data = pd.read_csv(weather_path)
weather_mo_df = pd.DataFrame(weather_data)
#weather_mo_df.head()

# %%
#Monthly crime CSV read & DataFrame
crime_path = "Output/CrimeData_Monthly.csv"
crime_data = pd.read_csv(crime_path)
crime_mo_df = pd.DataFrame(crime_data)

# %%
#Monthly weather rename columns for merging
weather_mo_df = weather_mo_df.rename(columns= {"ReportedYearMonth":"Month"})
#weather_mo_df.head()
# Out:
#      Month  Avg_temp
# 0  2018-01      18.0
# 1  2018-02      18.0
# 2  2018-03      34.0
# 3  2018-04      38.0
# 4  2018-05      69.0

# %%
#Merge Crime & Weather Monthly DataFrame
combined_monthly = pd.merge(crime_mo_df, weather_mo_df, on="Month")
#combined_monthly.head()
# Out:
#       Month  CrimeCount  Avg_temp
# 0   2018-01        1482      18.0
# 1   2018-02        1276      18.0
# 2   2018-03        1405      34.0
# 3   2018-04        1326      38.0
# 4   2018-05        1674      69.0
# 5   2018-06        1462      74.0
# 6   2018-07        1816      76.0
# 7   2018-08        1751      74.0
# 8   2018-09        1787      66.0
# 9   2018-10        1857      47.0
# 10  2018-11        1628      30.0
# 11  2018-12        1490      28.0
# 12  2019-01        1503      16.0
# 13  2019-02        1251      17.0
# 14  2019-03        1457      31.0
# 15  2019-04        1715      47.0
# 16  2019-05        2012      56.0
# 17  2019-06        2239      71.0
# 18  2019-07        2325      76.0
# 19  2019-08        2320      72.0
# 20  2019-09        2248      67.0
# 21  2019-10        2103      48.0
# 22  2019-11        1972      33.0
# 23  2019-12        1838      26.0
# 24  2020-01        1882      23.0
# 25  2020-02        1613      23.0
# 26  2020-03        1791      39.0

# %%
#Daily crime CSV read & DateFrame
daily_crime = "Output/CrimeData_Daily.csv"
daily_crime_df = pd.read_csv(daily_crime, encoding="ISO-8859-1")
#daily_crime_df
# Out:
#                                                                      <<<<<<< HEAD
# Day                                              CrimeCount NaN NaN           NaN
# 2018-01-01                                       40         NaN NaN           NaN
# 2018-01-02                                       51         NaN NaN           NaN
# 2018-01-03                                       55         NaN NaN           NaN
# 2018-01-04                                       47         NaN NaN           NaN
# ...                                                                           ...
# 2020-03-28                                       37         NaN NaN           NaN
# 2020-03-29                                       37         NaN NaN           NaN
# 2020-03-30                                       63         NaN NaN           NaN
# 2020-03-31                                       52         NaN NaN           NaN
# >>>>>>> 05a038a498effd28622379573a62b700d2eeab7d NaN        NaN NaN           NaN
#
# [1646 rows x 1 columns]

# %%
#Daily crime filter for JAN 19'
jan2019_df = daily_crime_df.loc[daily_crime_df["Day"] >= "2019-01-01"]
jan2019_df = jan2019_df.loc[jan2019_df["Day"] < "2019-02-01"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4e20e68e4cfd> in <module>
#       1 #Crime
# ----> 2 jan2019_df = daily_crime_df.loc[daily_crime_df["Day"] >= "2019-01-01"]
#       3 jan2019_df = jan2019_df.loc[jan2019_df["Day"] < "2019-02-01"]
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day'

# %%
#Daily crime filter for JUL 19'
jul2019_df = daily_crime_df.loc[daily_crime_df["Day"] >= "2019-07-01"]
jul2019_df = jul2019_df.loc[jul2019_df["Day"] < "2019-08-01"]

# %%
#Daily weather CSV read
daily_weather = "Output/Weather_AvgTemp_Daily"
daily_weather = pd.read_csv(daily_weather)
daily_weather = daily_weather.rename(columns = {"ReportedYearDay":"Day"})
#daily_weather

# %%
#Daily weather filter for JAN 19'
weath_jan2019 = daily_weather.loc[daily_weather["Day"] >= "2019-01-01"]
weath_jan2019 = weath_jan2019.loc[weath_jan2019["Day"] < "2019-02-01"]

# %%
#Daily Weather filter for JUN 19'
weath_jul2019 = daily_weather.loc[daily_weather["Day"] >= "2019-07-01"]
weath_jul2019 = weath_jul2019.loc[weath_jul2019["Day"] < "2019-08-01"]

# %%
#Merge Crime & Weather Daily JAN 19' & JUL 19' DataFrames
combined_daily_JAN = pd.merge(jan2019_df, weath_jan2019, on="Day")
combined_daily_JUL = pd.merge(jul2019_df, weath_jul2019, on="Day")
combined_daily_JUL = combined_daily_JUL.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])
combined_daily_JAN = combined_daily_JAN.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])

# %% [markdown]
# ### CREATE MONTHLY VISUALS

# %%
#Create DataFrame for monthly graphing
mo_linechart = combined_monthly.set_index("Month")
#mo_linechart.head()

# %%
#Monthly Average Temperature vs. Crime Count line chart
fig, ax1 = plt.subplots()

x_axis = np.arange(len(combined_monthly['Month']))

color = 'tab:blue'
ax1.set_xlabel('Month')
ax1.set_ylabel('Avg Temp', color=color)
ax1.plot(combined_monthly['Month'], combined_monthly['Avg_temp'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

fig.autofmt_xdate(rotation=90)

ax2 = ax1.twinx() 

color = 'tab:red'
ax2.set_ylabel('Crime Count', color=color) 
ax2.plot(combined_monthly['Month'], combined_monthly['CrimeCount'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

tick_locations = [value for value in x_axis]

plt.title("Monthly Average Temperature vs. Crime Count")
plt.savefig("Output/Monthly Average Temperature vs. Crime Count")
plt.show()

# %%
#Temperature vs. Crime Count scatter plot & regression
temp = combined_monthly['Avg_temp']
crime = combined_monthly['CrimeCount']

x_values = temp
y_values = crime

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,10),fontsize=15,color="red")

plt.xlabel ('Temperature')
plt.ylabel ('Crime')
plt.title ('Temperature vs. Crime Count ')
plt.show()
plt.savefig('Output/Temperature vs. Crime Count _Scatter')
print(line_eq)

# %%
#Create calculation forecasting temperature based off of the regression formula
combined_monthly['Forecast']= 8.87*combined_monthly['Avg_temp']+1349.35
#combined_monthly

# %%
#Create DataFrame for plotting the forecasted temperature vs. the actual temperature
forecast_df = combined_monthly.set_index("Month")
CrimeForecast_df = forecast_df.drop(columns='Avg_temp')
#CrimeForecast_df

# %%
#Crime Count vs. Forecasted Count line graph
CrimeForecast_df.plot(kind="line", figsize=(7,4))
plt.xlabel("Month")
plt.ylabel("Crime Count")
plt.title ("Crime Count vs. Forecasted Count")
plt.savefig('Output/Crime Count vs. Forecasted Count')
plt.show

# %% [markdown]
# ### CREATE DAILY VISUALS

# %%
#Create January daily line graph
fig, ax1 = plt.subplots()

x_axis = np.arange(len(combined_daily_JAN['Day']))

color = 'tab:blue'
ax1.set_xlabel('Day')
ax1.set_ylabel('Avg Temp', color=color)
ax1.plot(combined_daily_JAN['Day'], combined_daily_JAN['Avg_temp'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

fig.autofmt_xdate(rotation=90)

ax2 = ax1.twinx() 

color = 'tab:red'
ax2.set_ylabel('Crime Count', color=color) 
ax2.plot(combined_daily_JAN['Day'], combined_daily_JAN['CrimeCount'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

tick_locations = [value for value in x_axis]

plt.title("Daily Temperature vs. Crime Count - January")
plt.savefig('Output/TempvCrime_Daily_Jan')
plt.show()

# %%
#Create July daily line graph
fig, ax1 = plt.subplots()

x_axis = np.arange(len(combined_daily_JUL['Day']))

color = 'tab:blue'
ax1.set_xlabel('Day')
ax1.set_ylabel('Avg Temp', color=color)
ax1.plot(combined_daily_JUL['Day'], combined_daily_JUL['Avg_temp'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

fig.autofmt_xdate(rotation=90)

ax2 = ax1.twinx() 

color = 'tab:red'
ax2.set_ylabel('Crime Count', color=color) 
ax2.plot(combined_daily_JUL['Day'], combined_daily_JUL['CrimeCount'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

tick_locations = [value for value in x_axis]

plt.title("Daily Temperature vs. Crime Count - July")
plt.savefig('Output/TempvCrime_Daily_JUN')
plt.show()
